# %% [markdown]
# <a href="https://colab.research.google.com/github/bbberylll/ESAA_OB/blob/main/ESAA_OB_M07_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 문서 군집화: 비슷한 텍스트 구성의 문서를 군집화하는 것
# - 학습 데이터 필요 X, 비지도학습 기반
# - TfidfVectorizer: Lemmatization 같은 어근 변환은 지원 X, tokenizer 인자에 커스텀 어근 변환 함수를 적용해 어근 변환 수행 가능

# %% [markdown]
# 군집별 핵심 단어 추출
# - KMeans 객체는 각 군집을 구성하는 단어 피처가 군집의 중심을 기준으로 얼마나 가깝게 위치해 있는지 cluster_centers_라는 속성으로 제공
#     - 배열 값으로 제공, 행은 개별 군집, 열은 개별 피처

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import glob, os
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)

path=r'/content/drive/MyDrive/topics'
all_files=glob.glob(os.path.join(path, "*.data"))
filename_list=[]
opinion_text=[]


for file_ in all_files:
    df=pd.read_table(file_, index_col=None, header=0, encoding='latin1')

    filename_=file_.split('\\')[-1]
    filename=filename_.split('.')[0]

    filename_list.append(filename)
    opinion_text.append(df.to_string())

document_df=pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
#                                                       filename  \
# 0  /content/drive/MyDrive/topics/accuracy_garmin_nuvi_255W_gps
# 1            /content/drive/MyDrive/topics/video_ipod_nano_8gb
# 2    /content/drive/MyDrive/topics/staff_bestwestern_hotel_sfo
# 3          /content/drive/MyDrive/topics/buttons_amazon_kindle
# 4     /content/drive/MyDrive/topics/voice_garmin_nuvi_255W_gps
#
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def LemNormalize(text):
    lemmatizer=WordNetLemmatizer()
    return [lemmatizer.lemmatize(token) for token in word_tokenize(text)]

# %% [markdown]
# 군집화 기법: k-평균
# 5개의 중심 기반으로 군집
# 최대 반복 횟수: 100
#
#
# K-평균 군집화를 통해 어떤 문서끼리 군집되는지 확인. 문서의 유형은 전자제품, 자동차, 호텔로 되어 있으며 먼저 5개의 Centroid 기반으로 어떻게 군집화되는지 확인. Kmeans를 수행한 후에 군집의 Label 값과 중심별로 할당된 데이터 세트의 좌표값 구함.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect=TfidfVectorizer(tokenizer=LemNormalize, stop_words='english', \
                           ngram_range=(1,2), min_df=0.05, max_df=0.85)

feature_vect=tfidf_vect.fit_transform(document_df['opinion_text'])

# %%
from sklearn.cluster import KMeans

km_cluster=KMeans(n_clusters=5, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label=km_cluster.labels_
cluster_centers=km_cluster.cluster_centers_

# %%
document_df['cluster_label']=cluster_label
document_df.head()
# Out:
#                                                       filename  \
# 0  /content/drive/MyDrive/topics/accuracy_garmin_nuvi_255W_gps
# 1            /content/drive/MyDrive/topics/video_ipod_nano_8gb
# 2    /content/drive/MyDrive/topics/staff_bestwestern_hotel_sfo
# 3          /content/drive/MyDrive/topics/buttons_amazon_kindle
# 4     /content/drive/MyDrive/topics/voice_garmin_nuvi_255W_gps
#
# ...

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename')
# Out:
#                                                         filename  \
# 48       /content/drive/MyDrive/topics/comfort_honda_accord_2008
# 33       /content/drive/MyDrive/topics/comfort_toyota_camry_2007
# 38   /content/drive/MyDrive/topics/gas_mileage_toyota_camry_2007
# 29      /content/drive/MyDrive/topics/interior_honda_accord_2008
# 25      /content/drive/MyDrive/topics/interior_toyota_camry_2007
# 23       /content/drive/MyDrive/topics/mileage_honda_accord_2008
# 49   /content/drive/MyDrive/topics/performance_honda_accord_2008
# 43       /content/drive/MyDrive/topics/quality_toyota_camry_2007
# 27         /content/drive/MyDrive/topics/seats_honda_accord_2008
# 46  /content/drive/MyDrive/topics/transmission_toyota_camry_2007
#
# ...

# %%
document_df[document_df['cluster_label']==1].sort_values(by='filename')
# Out:
#                                                      filename  \
# 8    /content/drive/MyDrive/topics/battery-life_amazon_kindle
# 13   /content/drive/MyDrive/topics/battery-life_ipod_nano_8gb
# 30  /content/drive/MyDrive/topics/battery-life_netbook_1005ha
# 20   /content/drive/MyDrive/topics/performance_netbook_1005ha
# 9           /content/drive/MyDrive/topics/sound_ipod_nano_8gb
#
# ...

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename')
# Out:
#                                                         filename  \
# 26  /content/drive/MyDrive/topics/bathroom_bestwestern_hotel_sfo
# 14  /content/drive/MyDrive/topics/location_bestwestern_hotel_sfo
# 12     /content/drive/MyDrive/topics/location_holiday_inn_london
# 41        /content/drive/MyDrive/topics/price_holiday_inn_london
# 7          /content/drive/MyDrive/topics/room_holiday_inn_london
# 21     /content/drive/MyDrive/topics/rooms_bestwestern_hotel_sfo
# 22         /content/drive/MyDrive/topics/rooms_swissotel_chicago
# 2      /content/drive/MyDrive/topics/staff_bestwestern_hotel_sfo
#
# ...

# %%
document_df[document_df['cluster_label']==3].sort_values(by='filename')
# Out:
#                                                          filename  \
# 0     /content/drive/MyDrive/topics/accuracy_garmin_nuvi_255W_gps
# 3             /content/drive/MyDrive/topics/buttons_amazon_kindle
# 31  /content/drive/MyDrive/topics/directions_garmin_nuvi_255W_gps
# 40     /content/drive/MyDrive/topics/display_garmin_nuvi_255W_gps
# 37    /content/drive/MyDrive/topics/eyesight-issues_amazon_kindle
# 19                /content/drive/MyDrive/topics/features_windows7
# 32              /content/drive/MyDrive/topics/fonts_amazon_kindle
# 18          /content/drive/MyDrive/topics/keyboard_netbook_1005ha
# 10         /content/drive/MyDrive/topics/navigation_amazon_kindle
# 36   /content/drive/MyDrive/topics/satellite_garmin_nuvi_255W_gps
# 39      /content/drive/MyDrive/topics/screen_garmin_nuvi_255W_gps
# 15             /content/drive/MyDrive/topics/screen_ipod_nano_8gb
# 6             /content/drive/MyDrive/topics/screen_netbook_1005ha
# ...

# %%
document_df[document_df['cluster_label']==4].sort_values(by='filename')
# Out:
#                                                          filename  \
# 50          /content/drive/MyDrive/topics/food_holiday_inn_london
# 44           /content/drive/MyDrive/topics/food_swissotel_chicago
# 47       /content/drive/MyDrive/topics/free_bestwestern_hotel_sfo
# 34    /content/drive/MyDrive/topics/parking_bestwestern_hotel_sfo
# 35              /content/drive/MyDrive/topics/price_amazon_kindle
# 11    /content/drive/MyDrive/topics/service_bestwestern_hotel_sfo
# 42       /content/drive/MyDrive/topics/service_holiday_inn_london
# 28  /content/drive/MyDrive/topics/service_swissotel_hotel_chicago
# 5           /content/drive/MyDrive/topics/staff_swissotel_chicago
#
# ...

# %% [markdown]
# 군집 개수가 데이터에 비해 약간 많게 설정되어 있어서 더 세분화되어 군집화된 경향 있음. 중심 갯수를 5개에서 3개로 낮춰서 3개 그룹으로 군집화 함

# %%
from sklearn.cluster import KMeans

km_cluster=KMeans(n_clusters=3, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label=km_cluster.labels_


document_df['cluster_label']=cluster_label
document_df.sort_values(by='cluster_label')
# Out:
#                                                          filename  \
# 25       /content/drive/MyDrive/topics/interior_toyota_camry_2007
# 27          /content/drive/MyDrive/topics/seats_honda_accord_2008
# 29       /content/drive/MyDrive/topics/interior_honda_accord_2008
# 23        /content/drive/MyDrive/topics/mileage_honda_accord_2008
# 43        /content/drive/MyDrive/topics/quality_toyota_camry_2007
# 46   /content/drive/MyDrive/topics/transmission_toyota_camry_2007
# 38    /content/drive/MyDrive/topics/gas_mileage_toyota_camry_2007
# 33        /content/drive/MyDrive/topics/comfort_toyota_camry_2007
# 48        /content/drive/MyDrive/topics/comfort_honda_accord_2008
# 49    /content/drive/MyDrive/topics/performance_honda_accord_2008
# 15             /content/drive/MyDrive/topics/screen_ipod_nano_8gb
# 13       /content/drive/MyDrive/topics/battery-life_ipod_nano_8gb
# 0     /content/drive/MyDrive/topics/accuracy_garmin_nuvi_255W_gps
# ...

# %% [markdown]
# ## 군집별 핵심 단어 추출하기
# KMeans 객체는 각 군집을 구성하는 단어 피처가 군집의 중심을 기준으로 얼마나 가깝게 위치해 있는지 clusters_centers_라는 속성으로 제공 --> 배열 값으로 제공되며, 행은 개별 군집, 열은 개별 피처를 의미. 각 배열 내의 값은 개별 군집 내의 상대 위치를 숫자 값으로 표현한 일종의 좌표 값임.

# %%
cluster_centers=km_cluster.cluster_centers_
print('cluster_centers shape:', cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape: (3, 6155)
# [[0.         0.         0.         ... 0.         0.         0.        ]
#  [0.00163124 0.00119946 0.         ... 0.         0.         0.        ]
#  [0.         0.00040956 0.00090396 ... 0.00175541 0.00139053 0.00139053]]

# %%
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num,
                        top_n_features=10):
    cluster_details={}

    centroid_feature_ordered_ind=cluster_model.cluster_centers_.argsort()[:,::-1]

    for cluster_num in range(clusters_num):
        cluster_details[cluster_num]={}
        cluster_details[cluster_num]['cluster']=cluster_num

        top_feature_indexes=centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features=[feature_names[ind] for ind in top_feature_indexes]

        top_feature_values=cluster_model.cluster_centers_[cluster_num,
                                                          top_feature_indexes].tolist()

        cluster_details[cluster_num]['top_features']=top_features
        cluster_details[cluster_num]['top_features_value']=top_feature_values
        filenames=cluster_data[cluster_data['cluster_label']==cluster_num]['filename']
        filenames=filenames.values.tolist()

        cluster_details[cluster_num]['filenames']=filenames

    return cluster_details

# %% [markdown]
# dictionary를 원소로 가지는 리스트인 cluster_details 반환됨.
#
# cluster_details > 개별 군집번호, 핵심 단어, 핵심단어 중심 위치 상댓값, 파일명 속성 값 있음.

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('####### Cluster {0}'.format(cluster_num))
        print('Top features:', cluster_detail['top_features'])
        print('Reviews 파일명:', cluster_detail['filenames'][:7])
        print('=============================================')

# %%
feature_names=tfidf_vect.get_feature_names_out()

cluster_details=get_cluster_details(cluster_model=km_cluster, cluster_data=document_df,
                                    feature_names=feature_names, clusters_num=3, top_n_features=10)
print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['interior', 'seat', 'mileage', 'comfortable', 'gas', 'gas mileage', 'transmission', 'car', 'performance', 'quality']
# Reviews 파일명: ['/content/drive/MyDrive/topics/mileage_honda_accord_2008', '/content/drive/MyDrive/topics/interior_toyota_camry_2007', '/content/drive/MyDrive/topics/seats_honda_accord_2008', '/content/drive/MyDrive/topics/interior_honda_accord_2008', '/content/drive/MyDrive/topics/comfort_toyota_camry_2007', '/content/drive/MyDrive/topics/gas_mileage_toyota_camry_2007', '/content/drive/MyDrive/topics/quality_toyota_camry_2007']
# ...
# ####### Cluster 1
# Top features: ['screen', 'battery', 'keyboard', 'battery life', 'life', 'kindle', 'video', 'direction', 'voice', 'size']
# ...
